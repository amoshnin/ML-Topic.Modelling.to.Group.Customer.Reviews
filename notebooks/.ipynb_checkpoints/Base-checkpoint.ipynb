# %% [markdown]
# ## Theory: Introduction to Topic Modelling

# %% [markdown]
# In this blog we will learn about topic modelling (or how to identify topics in a given corpus of text).
#
# The problem of topic modeling has become increasingly important in the last decade as our society has become more digitalized, with increased use of online platforms such as social media, which, combined with advances in storage capacity technologies, has resulted in an exponential increase in the amount of unstructured data available to us, with text data being one of the most common types.
#
# However, all this data that is becoming increasing available has a lot of information associated with it, which makes it difficult for us to find exactly what we're looking for. As an analogy, finding a certain sentence on a page is considerably easier than finding it in an entire book.
#
# So, we need tools and techniques to organise/search/understand the vast quantities of information.
# 1. Firstly, we need to organise the data. Because at this moment most of the data is not organised in any manner.
#     - ex: text data on social media platforms (twitter/instagram) is unorganised
#     - ex: text data on customer reviews is unorganised
# 2. Secondly, wee need to be able to search from it
# 3. Thirdly, understand the information that is present in the data
#
# Topic modelling provide us with methods to (organise/search/understand) by summarising the logical actions of textual information that is present in the data. It helps:
# 1. Discover the hidden topical patterns that are present in the collection
# 2. Annotate the data, so that it can be used further on based on the topics that have been identified
#
# Topic modelling can also be described as a method for finding a group of words from a collection of documents that best represents the information in the collection. It can also be thought of as a form of text mining, because you're mining a vast amount of textual information.

# %% [markdown]
# In order to do this, we will be using unsupervised machine learning techniques because our data is unlabelled, which is help us in clustering/grouping this data (ex: customer reviews) to identify the main ideas/topics in a corpus of text.
#
# In this blog we will use a real-world twitter textual corpus of data. However, note that the same techniques will apply to any corpus of text. This corpus of text was web-scraped directly from the twitter data and therefore it will have all the characteristics that any real-world corpus of text will have with things like: people have their own coloquial language, presence of noise. So, we will learn how to clean the noise and use that data for clustering to identify the main topics that people are talking about. Then, depending on whatever is the business decision, they can take certain steps towards it.
#
# In order to do so, I will be using the NLTK (Natural Language Toolkit) package.

# %% [markdown]
# ## Theory: Introduction to NLTK (Natural Language Toolkit)

# %% [markdown]
# NLTK provides us with tools that enable us to make the computer understand natural language. It's the leading library for building python programmes to work with human language data.
#
# For a computer, it's very easy to interpret programming language as they follow a specific syntax enabling the computer to parse it with any problems. However, human language is a very unstructured form of data, which means that the same thing can be said in a variety of ways and it means the same thing.
#
# - For example, sentences "I hope you're doing well" and "I hope everything is fine with you", both have the same meaning and use similar words, however, the way they're structured is different. Hence, for a computer these two sentence are basically different sentences which can mean different things.
#
# - NLTK is one of the tools that help computers clean and preprocess the human language data in such a way that makes it more structured such that computers can understand it.
#
# NLTK provides quite an easy to use interface and it has a suite of text processing libraries, for things like:
# - **Classification**
# - **Tokenisation** => sepparating out the words and removing punctuation
# - **Stemming** => since same word can have prefixes/suffixes, stemming will cut all these prefixes/suffixes & get the core of the word which still has the same meaning (ex: words "stemming", "stemmer" => can be stemmed to the word "stem")
# - **Tagging** => each word can be gramatically tagged - whether it's (an article, a verb, a noun, an adjective, etc)
#
# Finally, the best thing is that NLTK is free and open source, so if you want you can even contribute to it as it is a community driven project.
#
# Here is the link to [GitHub Repository of NLTK](https://github.com/nltk/nltk)
#
# The way to use NLTK is just like any other python library, you can directly import it:
# ```python
# import nltk
# ```
# However, initially you would have to install NLTK and given that it has a vast suite of tools that are available for a variety of tasks - usually you don't require all of them and to install all of them would take you a very long time.
#
# Therefore, instead of installing the whole NLTK package, you can install parts of it on your machine. To do so, NLTK provides a very nice GUI.
#
# <img src="./images/nltk-gui.png" alt="Drawing" style="width: 500px;"/>
#
# If you know the speicifc tools that you're going to use, go to "Corpora", search for them and download them:
#
# <img src="./images/nltk-gui2.png" alt="Drawing" style="width: 500px;"/>
#
# For example, here I've installed the stopwords sub-package because this is something that I commonly use to remove all words that esentially don't convey any meaning (they usually tend to be words that are articles):
#
# <img src="./images/nltk-gui3.png" alt="Drawing" style="width: 500px;"/>
#
# Fuerthermore, you can also download models for implementing transfer learning:
# <img src="./images/nltk-gui4.png" alt="Drawing" style="width: 500px;"/>
# (for example, this model Word2Vec is quite famously used amongst NLP Data Scientists)
#
# Then, once your required sub-packaged gets downloaded, you import it like any other python packge:
#
# ```python
# from nltk import stopwords
# ```

# %%
import nltk
nltk.download_gui()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %% [markdown]
# ## Practise: Loading and Exploring Twitter Data

# %% [markdown]
# Importing libraries

# %%
import nltk
import numpy as np
import pandas as pd
import re # regex

# %% [markdown]
# Perform configuration of settings

# %%
# Get multiple outputs in the same cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings(action="ignore", category=DeprecationWarning)

# %%
# Display all rows and columns of a DataFrame instead of a truncated version
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# Because this is a real-world corpus of text gathered through web-scraping Twitter, it's more complicated in the sense that there's a lot of noise and coloqualiasms, so it's not a set of grammatically correct phrases like you'd find in literature or articles.

# %%
raw_data = pd.read_csv("../data/data.csv", encoding="ISO-8859-1")
# Out:
# (21047, 4)
#         username        date  \
# 0  shivaji_takey  10-06-2020
# 1  sarasberiwala  10-06-2020
# 2     chitreamod  10-06-2020
# 3   sanjan_suman  10-06-2020
# 4       t_nihsit  10-06-2020
#
#                                                tweet        mentions
# 0  Please check what happens to this no 940417705...  ['vodafonein']
# 1  Network fluctuations and 4G Speed is pathetic....  ['vodafonein']
# 2  This has been going on since 3rd... this absol...  ['vodafonein']
# 3  @VodafoneIN  I have done my recharge of 555 on...  ['vodafonein']
# 4  But when???Still I am not received any call fr...  ['vodafonein']

# %%
raw_data.shape
raw_data.head()
# Out:
# (21047, 4)
#         username        date  \
# 0  shivaji_takey  10-06-2020
# 1  sarasberiwala  10-06-2020
# 2     chitreamod  10-06-2020
# 3   sanjan_suman  10-06-2020
# 4       t_nihsit  10-06-2020
#
#                                                tweet        mentions
# 0  Please check what happens to this no 940417705...  ['vodafonein']
# 1  Network fluctuations and 4G Speed is pathetic....  ['vodafonein']
# 2  This has been going on since 3rd... this absol...  ['vodafonein']
# 3  @VodafoneIN  I have done my recharge of 555 on...  ['vodafonein']
# 4  But when???Still I am not received any call fr...  ['vodafonein']

# %% [markdown]
# Based on the shape of our dataframe, we see that we will be working with 21047 tweets in total. This particular twitter data only include tweets that have mentions of vodafone, which is a telecom company.

# %% [markdown]
# Now, let's perform some sanity checks to help us understand whether our dataset have any issues we need to handle

# %% [markdown]
# First, let's check whether there're any duplicate tweets:

# %%
unique_text = raw_data["tweet"].unique()
print(len(unique_text))
# Out:
# 21047

# %% [markdown]
# Since number of unique tweets equal to number of rows, then we don't have any duplicates.

# %% [markdown]
# Let's look in detail at some individual tweets:

# %%
raw_data["tweet"][4]
# Out:
# 'But when???Still I am not received any call from customer care.Very poor services.'

# %% [markdown]
# Just from looking at a few tweets, there seems to be a lot of complaints, which seems logical as people usually go to twitter to get their complaints noticed more quickly or raise awareness.

# %% [markdown]
# At the same time, we see that there're a wide variety of topics mentioned, even in this small number of tweets that we have seen.
#
# We have 21047 tweets that has been gathered in a very short duration. Given this large number of tweets, it would be almost impossible for a person to go through all the tweets and figure out the topics that are present and be able to identify which area needs the most addressing (maybe it's the service area or network area or number porting area).

# %% [markdown]
# ## Practise: Cleaning the Data with Pattern Removal

# %% [markdown]
# So, from previous exploration we've found out that we're using tweets addressed to specific telecommunication company, Vodafone. From exploring just a few tweets we realised that there're various topics that are present in the twitter corpus that we will be using as our textual input to the unsupervised machine learning model that we want to implement.

# %% [markdown]
# Now, we will take the first steps of cleaning this data.

# %% [markdown]
# Function below will help us remove certain patterns from the data:
#
# It takes in as (input=text) and (pattern that we're looking at removing) and using the regex library it will find this particular pattern in all the input data.

# %%
def remove_pattern(input_text, pattern):
    r = re.findall(pattern, input_text)
    for i in r:
        input_text = re.sub(i, '', input_text)
        # result = re.sub(pattern, repl, string);
        # replacing all the found patterns with an empty string
    return input_text

# %% [markdown]
# Above, is a generic function to which you can give any pattern and any input text - it will remove the pattern and give you back the input text.

# %% [markdown]
# #### First step will be to remove any @ mentions
# Because all of this data will be addressing Vodafone only either way, so having @Vodafone doens't add any useful information. Having @Vodafone present in all the tweets would act as noise for the algorithm.

# %%
# np.vectorize is a convenient way of writing a for-loop
# it will loop through all the values in raw_data["tweet"] pandas Series

# pattern that we want to remove is, @[\w]*, any word starting with @
raw_data["clean_text"] = np.vectorize(remove_pattern)(raw_data["tweet"], "@[\w]*")
raw_data["clean_text"]
# Out:
# 0        Please check what happens to this no 940417705...
# 1        Network fluctuations and 4G Speed is pathetic....
# 2        This has been going on since 3rd... this absol...
# 3          I have done my recharge of 555 on 9709333370...
# 4        But when???Still I am not received any call fr...
# 5         mere area me vodafone ka network nai aa raha ...
# 6        Thanks, but I have visited the website, called...
# 7         \nHi,\n Today my Vodafone cim is deactivated ...
# 8        Dear Vodafone, I have already responded to you...
# 9         SIR OUR MARKET AREA ME BILKUL NETWORK NAHI AA...
# 10          Why the hell Previous plan Deactivated of 2...
# 11       Vodafone Netwrk is worst ever...Using from so ...
# 12        9796053999... internet not working, pls assis...
# 13                        Still waiting for your reply
# 14       Reverse migration ka zamana hai dear Alu. Kar ...
# 15        Unable to access your website and is showing ...
# 16       Worst customer care, I charged 1072 for intern...
# 17        Ã Â¤ÂÃ Â¥ÂÃ Â¤Â¯Ã Â¤Â¾ Ã Â¤Â«Ã Â¤Â¾Ã Â¤Â¯Ã ...
# 18        call drops are very high.\nThis is 4th day m ...
# 19       Please help with the exact process of changing...
# 20
# 21               I haven't received any message Or update.
# 22                                              9955847531
# 23                             Can I expect your response?
# 24        .. when u can assure your customers that ur s...
# 25        gonna port into ur network hope it works out ...
# 26       Someone has misused my documents to get a sim ...
# 27                               Bari jaldi reply aa gaya.
# 28       Sent you a private message on Monday night its...
# 29       We have already used the link and done so Pia....
# 30       Navyug market, ghaziabad, uttar praders, pleas...
# 31       Do not buy internet service from you broad ban...
# 32        such a sorry state of affairs . Your south ex...
# 33       Very bad network coverage by Vodafone. Call dr...
# 34       Super fast   4G+ network... Thank you   pic.tw...
# 35        After complaining again and again no one has ...
# 36       If you can't provide the speed ir sufficient n...
# 37        Why don't vodafone provide any recharge offer...
# 38        My complaints reference # CC004-67991604556 s...
# 39       Pathetic network of vodafone & they say they h...
# 40        11th consecutive day still my issue is same. ...
# 41       Request for a call back..You committed the sam...
# 42       My purpose still not solved aftet manually net...
# 43             9925708233 no response till now check my DM
# 44       Hello Rekha, dailing *1 to skip the advisory d...
# 45                       Required details DM kindly reply.
# 46        How is one supposed to pay bill when your sit...
# 47        i m facing no network coverage at my home. tr...
# 48       Are bhai ye company wale he mc mera bhi   ka s...
# 49       K-Fon varum ellam Sheriyakum...paisa evide nin...
# 50        spotify is not working only on your data plat...
# 51        My contacts are saying they are getting my ca...
# 52                            Inbox my details.  Pls check
# 53       DM not going due to number not working for ver...
# 54        \nHi,\nI have provided the details yesterday....
# 55        this is happening since morning and happens e...
# 56        Don't you'll think it's high time this annoyi...
# 57       Same here. Our services are down and  isn't re...
# 58        \nNo sense in complaining to  ,Such a worst n...
# 59       This is your internet speed, complaining again...
# 60        I hv taken ur survey and i hope u will able t...
# 61       May be because the network is pathetic and it ...
# 62        \nToo much slow network before one week ... f...
# 63       . \n\nHow can I get call details record of Apr...
# 64         I would expect a brand like Vodafone with a ...
# 65       Vilpower (Vodafone-Idea) charged us Rs 5,000 t...
# 66                              \nToo much slow network ..
# 67                                                    help
# 68                   Msged you the number. Please respond.
# 69         So far no one called me to get the feedback....
# 70       With heavy heart I parted ways with Airtel to ...
# 71       I did not subscribe for any Re.1 service!! Did...
# 72       Hey  , can I go for a contactless / without vi...
# 73        again no network. I am porting out.  pic.twit...
# 74                                              No revert
# 75                                You never replied on DM.
# 76         Worst ever 4G experience. No support at all....
# 77       Your Tweet has been forwarded to the concerned...
# 78       Hey   I am all set to port my  number to you g...
# 79       You have already taken information twice, only...
# 80        has the worst customer service, they harass t...
# 81       How many times do I have to DM my details. Its...
# 82        any update??? You guys are looking since 10 d...
# 83       I have the same issue over past 3 months. YOu ...
# 84       What u will do after getting my details?  Ever...
# 85        I am still waiting for my postpaid SIM. My or...
# 86                                            Sent..Thanks
# 87       Either you can on 9620051511 or please provide...
# 88       Yeah. They keep spamming with different packag...
# 89        Looks like your network is forever in lockdow...
# 90                                              \n\n\n\n\n
# 91        no response from your end. I don't know why y...
# 92       Whys do you even bother to ask mobile nymber w...
# 93       Check the number from where it was process & y...
# 94        I am using connection for more than 10 ye and...
# 95        Social media team is not responding to any DM...
# 96       Arre didi.. ek saal ho gyaa mjhe apna number p...
# 97       Vodafone only Loot the client. If you not hara...
# 98                                                  Hahaha
# 99        what is wrong with your back office? Why are ...
# 100      \n\n\n\n\n\n\n \n8007800300, For number  I had...
# 101      Kar le bhai, ladki khud se aage hokar bol rahi...
# 102      No no not at all .........but Idea -voda is pr...
# 103       i had done plan for 3 gb per day....but vodaf...
# 104                                     Thank you Ã°ÂÂÂ
# 105                                also does this Ã°ÂÂÂ
# 106       no 4g network in entire south Goa. Can you pl...
# 107      In ur link it's shown that, FRC can be done wi...
# 108      My sim showing no service while rechrge is val...
# 109       Dear Team, I still didn't get any respons fro...
# 110      I want to port my   number to  .\nAny doorstep...
# 111      Dear  . Finally some how I got message for you...
# 112       Ã°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂ  My previous...
# 113       i was using Vodafone number 8920637881, befor...
# 114                              World third class network
# 115      I have even e-mailed them but no reply at all ...
# 116        is The Worst Company Ever i have Exchanged s...
# 117        \n\nPlease share the process of activating a...
# 118                        really very 'high' HDI state :P
# 119      Hi! I understand how inconvenient this could b...
# 120       now I have also made another payment for 600/...
# 121        ...but further, upon getting through to thei...
# 122      Yes it's  very true. I am so fed up i port out...
# 123      Worst service provider, plz don't buy Voda sim...
# 124       Ã Â¤Â¸Ã Â¤Â°,,2 Ã Â¤Â¦Ã Â¤Â¿Ã Â¤Â¨ Ã Â¤Â¹Ã Â¥...
# 125      Ã Â¤ÂµÃ Â¥ÂÃ Â¤Â¡Ã Â¤Â¾Ã Â¤Â«Ã Â¥ÂÃ Â¤Â¨ Ã Â...
# 126      God knowns when the call will come \n#waiting ...
# 127      Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£ Ã Â¤ÂÃ Â¥ÂÃ Â¤ÂÃ Â¤Â­Ã Â¤Â...
# 128        We only chose YOU for WiFi services because ...
# 129       ,more than 10 days,still not clear how you ha...
# 130      Here comes the standard reply. Your customer c...
# 131       Please Return my Ã¢ÂÂ¹69 of Callertune charg...
# 132      Since when you started charging for the calls ...
# 133       \nHow did the Vodafone cheat on me? He give m...
# 134      Hi Suresh, Please reach out us at support.in w...
# 135      Hi Sivakumar, Please reach out us at support.i...
# 136      If u guys really want to provide service. I th...
# 137                                       Ã°ÂÂÂÃ°ÂÂÂ
# 138      Hi Sandipan, Please reach out us at support.in...
# 139       \nYour own following message gives feedback o...
# 140       #boycott Vodafone because this telecom operat...
# 141                          My sim is lost how will i get
# 142                              Msgs already.. reply asap
# 143       Severe Network issue in shakti nagar area del...
# 144       I don't understand whats wrong with Vodafone ...
# 145       Should I take it as bad feedback for  ? Ã°ÂÂÂ
# 146                    Ã Â¤Â®Ã Â¤Â¹Ã Â¤Â¾Ã Â¤Â°Ã Â¤Â¾Ã ...
# 147      Funny!  Turbonet 4G services are so fast that ...
# 148              Same here, did they get it fixed for you?
# 149      Very disappointing network and bad connectivit...
# 150      Not getting any store, call or email solutions...
# 151      Hey  \n \nCan we get a blocklist for promotion...
# 152       on DND list yesterday and today again got the...
# 153
# 154       #poorservice \nI am facing issue with the Vod...
# 155      Outage for a week from 3rd June. Everyday made...
# 156       I am unable to send messages from my phone ev...
# 157      I am complaining to  already,inbox my number i...
# 158         Hey Robber network, is there any update on ...
# 159                                       really does suck
# 160                                       really does suck
# 161       From my account deduct the Rs 35.I donÃ¢ÂÂt...
# 162      \n\n\n#Vodafone has put RedX charges of 1000 +...
# 163      Ã Â¤ÂªÃ Â¤Â¹Ã Â¤Â²Ã Â¥Â Ã Â¤Â
# Ã Â¤ÂªÃ Â¤Â¨Ã Â...
# 164      I have never seen so much nonsense network.   ...
# 165      Now I called customer care executive harjinder...
# 166      \nI am channel partner of Vodafone of Meerut Z...
# 167       Customer support of no use, Vodafone app of n...
# 168      Worst network- Vodafone! No service from last ...
# 169              Wapas aa jao Telecom mein, Sirji Ã°ÂÂÂ
# 170      Shame on   https://twitter.com/FT/status/12704...
# 171      Its there to waste your time. So you give up a...
# 172      \n\n\n\n \nVodafone Idea Ltd...  Customer serv...
# 173       you have activated scheme by your own and dai...
# 174             Still there is no response from your side.
# 175               Minimum 15 promotional messages in a day
# 176       is worst. There are minimum 15 messages in a day
# 177      Ã Â¤Â®Ã Â¥ÂÃ Â¤Â°Ã Â¥Â Ã Â¤Â¨Ã Â¤ÂÃ Â¤Â¬Ã Â...
# 178        your deadline for call back that was 9th jun...
# 179              They called they have asked to go to shop
# 180      The DLT SMS header approval process is still p...
# 181        is this the way you treat all your customers...
# 182      Can you confirm if this one is open as well:\n...
# 183      Ã Â´ÂÃ ÂµÂÃ Â´Â°Ã Â´Â³Ã Â´Â¤Ã ÂµÂÃ Â´Â¤Ã Â´...
# 184         Alert for All vodafone subs. I received a c...
# 185      This is the case with almost all NW signals. R...
# 186      Dear  have been a cust 4 a long time nd always...
# 187                       Ã°ÂÂÂmust be a direct uplink.
# 188      You can do it online go to  http://airtel.inÃ...
# 189                   Still I am waiting for your response
# 190      I really am thinking of doing this! There has ...
# 191        Dear Sir do help to get solution of this net...
# 192      Best network by  ported to  pic.twitter.com/vZ...
# 193       Ã°ÂÂÂbareilly . Pip bareilly Ã°ÂÂÂÃ°ÂÂ...
# 194       Hello! Your complaint dated 24-May-2020 01:04...
# 195      What r u working on? What assurance? No action...
# 196       ur pathetic network service.. but still charg...
# 197                              No one has contacted yet.
# 198      Have already done that on 31st May. No correct...
# 199                         An  can also change the life..
# 200          as you requested details  provided I am wa...
# 201        vodafone n toh contact karne ki kosis karta ...
# 202                             pic.twitter.com/Quf1Ao3xaJ
# 203      Useless  ... \n115GB left  .... It will soon t...
# 204      Haven't heard from you, so I reckon Vodafone i...
# 205       call drop problem is very high since last two...
# 206      Not get any Response from  team after take my ...
# 207                 why no network ?? So much network drop
# 208       Ã Â¤Â
# Ã Â¤ÂÃ Â¤Â° Ã Â¤ÂÃ Â¤Âª Ã Â¤Â
# Ã Â¤ÂªÃ...
# 209                                            Ok I'm wait
# 210      Pathetic. First- you couldnÃ¢ÂÂt port a numb...
# 211      No use in sending that SMS. I'm still getting ...
# 212      all have moved into voice over wifi ; within c...
# 213      Dear Team,\nI had already provided contact det...
# 214       need clarification on this one.  pic.twitter....
# 215      Nobody contacted me. .. i am expecting to get ...
# 216      So I request   to look into these as customer ...
# 217      Please check your Twitter chat I just respond ...
# 218      Vodafone is very bad Ã¢ÂÂÃ°ÂÂÂ«Ã°ÂÂÂ«Ã°Â...
# 219       Hi Team, i had ported my no. from Voda to Air...
# 220        \n\nHello,\nTrying to shift my network from ...
# 221               I m not able to make calls (from Punjab)
# 222        \n\nIs this your code of conduct? Your Value...
# 223       Are your stores open in Mumbai.. Visited 2 st...
# 224      Ques - is this signal of  ,  or  or  ? Ã°ÂÂ¤Â...
# 225                \n\nI'm literally tired now. Why is ...
# 226        \n  \ncan you guys please stop the "corona m...
# 227        . Today morning my wife received a call from...
# 228      When I ask for evidence don't receive answer. ...
# 229       when the hell will you call me???\nwhen i swi...
# 230      In the month of Jun 2020, I noticed spike in m...
# 231      I shared all the info, still no response. Good...
# 232       I hv been charged for intÃ¢ÂÂl roaming in M...
# 233      Hi.. I have almost non existent data in the da...
# 234           Network to  user  pic.twitter.com/5ZESeuLCQk
# 235              I m yet to get revert Today is Day 4 !!!!
# 236                           Is anyone gonna follow up ??
# 237      Alrdy done basic trouble shooting step.sim ins...
# 238           No Call Received. Very Poor Customer Service
# 239       #Kengeri branch has 4 Customer Service  Execu...
# 240                Can i Have any updates upon the issue ?
# 241       thanks for being the worst and most pathethic...
# 242      . \nI want to go for double data offer but you...
# 243      When you miss you bill payment due date -  pla...
# 244      I tired to follow  now i cant tolerate you. to...
# 245      Yes buddy but want to avoid as lot of cases ne...
# 246       why cant you call me????? \npathetic service ...
# 247      Kindly help Vodafone stores not operating Voda...
# 248      Please resolve the problem!! I am still facing...
# 249                      Just goto airtel store and port .
# 250       Use Jio or Airtel...\nIndian companies..Ã°ÂÂÂ
# 251         \nFollowings r d only ones which came into ...
# 252      Same I already complaint about airtel 2 years ...
# 253      No need to reply anymore.  already approached ...
# 254      My complain still not resolved!!! What is goin...
# 255      You may need to buy some stake in Jio platform...
# 256          are setting up new highs of the quarter lo...
# 257      Hi Team,\nI want to move my no from Vodafone  ...
# 258      I want to port my  number to . Any doorstep se...
# 259       I wanna hook up with you, got bored of  . . ....
# 260      I've been using vodafone since past 4 yrs.I'm ...
# 261      Is there any work started? I shared all requir...
# 262      See this network I'm using is that bad that I ...
# 263        I set my caller tune 3 week ago, you charged...
# 264       I don't get it, what do you mean by "clubbed ...
# 265      No one did call me or even worked on the conne...
# 266       really froud company u just wants bill amount...
# 267                                 Help soon. Read my DM.
# 268      Man, you should see what   has started. Even t...
# 269      I am unable to find low cost plan in my Vodafo...
# 270      I don't get it, what do you mean by "clubbed t...
# 271      . Ã Â¤ÂµÃ Â¤Â¾Ã Â¤Â²Ã Â¥Â Ã Â¤ÂÃ Â¤Â² Ã Â¤Â...
# 272      switch to   or   waise b delhi bas ki nahi air...
# 273       \nDon't get ur hopes high. \n is only asgooda...
# 274                No need! I am planning to switch to jio
# 275         PM want WFH and the service provider has no...
# 276      On every DM   sending robotic message.. not on...
# 277      They aren't responding buddy.\nSent them a dm ...
# 278        The best thing on Jio network in my Area is ...
# 279      Still waiting for the resolution. Pathetic ser...
# 280      This is how after I received the call from #ai...
# 281      already Replied to you. \nBut I don't think yo...
# 282        #DOTseva Nothing works,neither YouTube,nor t...
# 283      its more then one week over still issue Not re...
# 284       Ã Â¤ÂµÃ Â¥ÂÃ Â¤Â¡Ã Â¤Â«Ã Â¥ÂÃ Â¤Â¨ Ã Â¤ÂÃ ...
# 285      Worst service, worst connection ...just showed...
# 286       #nothelping what the hell you're talking abou...
# 287                                          worst service
# 288      This is the same copy n paste message Ive been...
# 289        Call customer service\nVodafone is crap anyways
# 290        Today I reinserted my Airtel sim and got a m...
# 291       Pathetic service by . Not getting a signal on...
# 292      Dude!! YouÃ¢ÂÂre of no help! I need to solve...
# 293      Shameless people's called me and asking me why...
# 294       Hello! complaint number C004-67762729018 was ...
# 295      ThereÃ¢ÂÂs no response or acknowledgement to...
# 296      I was calling them on daily basis, but there i...
# 297       after taking my details I thought vodafone is...
# 298       \n\nWhat is going in you company if the custo...
# 299       _OHD please see the attached images.  offers ...
# 300        it been more than a month. I have also paidm...
# 301      I am only attending call drops not calls. Wors...
# 302      Dear  I have ported my number into  due to wor...
# 303      IVRS is the unintelligent cousin of AI , thoug...
# 304      bahut cutiya company hai \n\nAgai i got msg fr...
# 305       if u people donÃ¢ÂÂt want to give 4g servic...
# 306       it would be better if you provide the network...
# 307      Tried that since yesterday I switched off my p...
# 308      Replied. Please resolve as soon as possible. I...
# 309       Is your site down? I had been trying to acces...
# 310           Worst service I have seen from any provider.
# 311       stop reminding me of the bill payments and st...
# 312                                                  Done.
# 313       My DLT registration no VI 1100023865 submitte...
# 314      Ã Â¤ÂÃ Â¥ÂÃ Â¤Â¯Ã Â¥ÂÃ Â¤Â Ã Â¤Â
# Ã Â¤Â¨Ã Â...
# 315       can you tell me how to talk yo an agent in th...
# 316      I change my mind already, dealing with worthle...
# 317                  #uselessservice #no network #no speed
# 318         could you please help me to get MNP on my d...
# 319      I dont care about this. But i really care is t...
# 320       please let me know how many times I would hav...
# 321      Hello #airtel disaster, still not awake? Alway...
# 322                   Already complaint and issue resolved
# 323       if you can help and \n  please help me with y...
# 324      Anyone tweet on twitter, instantly you replied...
# 325                                  My  number 9719727168
# 326                                          Check your dm
# 327      Issue resolved.Thanks  for your prompt respons...
# 328       \nRespected Mangalam sir,\nVoda has strtd cht...
# 329      For me, it's  who keep sending multiple SMS ev...
# 330       from last 2 days vodafone 4g is not working i...
# 331       #replytweet #VodafoneIdea #Vodafone  #boycott...
# 332                            Same thing is done by  too.
# 333           \nRc'd the following msg on 06.06.20 & it...
# 334       \n\nPlease 1st provide good network connectio...
# 335                                       Ã°ÂÂÂÃ°ÂÂÂ
# 336       \nNot again! Again the 4g network gone in som...
# 337         \nReceived the following msg on 06.06.20\n\...
# 338                                              Very good
# 339        \nReceived the following msg on 06.06.20\n\n...
# 340        I am struggling to get a postpaid number dis...
# 341      Ã Â¤ÂÃ Â¤ÂÃ Â¤Â¡Ã Â¤Â¿Ã Â¤Â¯Ã Â¤Â¾ Ã Â¤Â¸Ã Â...
# 342                                   very slow networking
# 343      I cant Make international call from my Vodafon...
# 344                                No response till now
# 345          Change network Vodafone very  slow networking
# 346       Waiting on complaint call since 20 mins no re...
# 347                               Thanks. So I'm not alone
# 348       I have tried my best and I messaged all the d...
# 349       This happened yesterday. Without any notice o...
# 350      The unlimited double data offer , after the fi...
# 351       https://www.google.com/amp/s/www.thehindubusi...
# 352       \n\n3rd Class corporate Customer care,\nworst...
# 353      No response after DM to   still facing the iss...
# 354                network bhut slow hai 3,4 din se aesa q
# 355      Hi team  .. \nExperiencing network issues from...
# 356       Hi why it say Vodafone be safe 3G, when yours...
# 357      I have sent all details on DM. And please for ...
# 358          Hi Team, still I'm waiting for your response.
# 359       unable to call STD (South India) land line nu...
# 360      My wife holds prepaid Vodafone connection wher...
# 361       I unable  send text messages from yesterday ....
# 362        Thats fine. But you are requested to unblock...
# 363                       very bad service by Vodafoneidea
# 364          Please check inbox I have send my details you
# 365                       Ã°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂ
# 366      Issue has not been resolved as yet. Since no o...
# 367       \nApp apni company Close kar do ji....\nLondo...
# 368       or  can you assure me your network quality..\...
# 369                      DoesnÃ¢ÂÂt it need port number?
# 370       \nCovid19 is Lockdown is over. So can we expe...
# 371      Yo keep closing, i am not even getting network...
# 372       I've recharged with Ã¢ÂÂ¹449 UL Calls,2+2GB ...
# 373       \nGive me proper network first plz...Ã°ÂÂÂ...
# 374      Hi  suddenly I'm not able to send sms from num...
# 375      You guys left me with no choice .. since Febru...
# 376      Vodafone is so dedicated with their support th...
# 377             I ave already sent the both. Please check.
# 378      Aur bhai  ki haal chaal? Sab theek? Mere yaha ...
# 379         never expect from you the worst service. No...
# 380       Hello do we still have a Vodafone customer ca...
# 381      Dear donÃ¢ÂÂt port in   ,because I am suffer...
# 382                                                  Sent.
# 383       This is so very shameful that my request of e...
# 384       it's been two days that I am not getting any ...
# 385        Ihave sent my number in the DM. I donÃ¢ÂÂt...
# 386               HavenÃ¢ÂÂt received any call yesterday
# 387          Hi tem facing very poor connectivity in ji...
# 388      I donÃ¢ÂÂt think you can fix your network qu...
# 389        What a shameful move by you people that you ...
# 390      When i doing online money transaction network ...
# 391                      Yes waiting for it. Hope it comes
# 392      Plz send me bills of last one year. ..  never ...
# 393       it's been 3 days since no range for my sim ca...
# 394      Send you the message directly. Hoping for fast...
# 395      Ghanta concirn after someday you will forget t...
# 396      Hello,, thanks for showing your concern. My pr...
# 397      36 hour passed i still waiting for your reply....
# 398        Ã Â¤ÂÃ Â¥ÂÃ Â¤ÂªÃ Â¤Â¯Ã Â¤Â¾ Ã Â¤Â®Ã Â¥ÂÃ...
# 399      Ã Â¤ÂµÃ Â¥ÂÃ Â¤Â¡Ã Â¤Â¾Ã Â¤Â«Ã Â¥ÂÃ Â¤Â¨ Ã Â...
# 400      Please can u confirm if the money wrong debite...
# 401      Utterly disappointed with you 4G services and ...
# 402       \nSo finally after so many calls and mails,I ...
# 403                                              Sent a Dm
# 404      Hi  , I have 2 Post paid connections and I wou...
# 405      Thank u Mac. Have DM u the numbers. Hope atlea...
# 406       hello my cellphone number has been allocated ...
# 407      Exactly ! That's the issue ! Your network is s...
# 408      I have received no response from your side to ...
# 409      Are you guys doing a case study or something ....
# 410      I use to think it only happens to me that the ...
# 411                        \nTPS,UKAIDAM, gujarat \n394680
# 412        see, i don't have any prblm with internet, i...
# 413                                             9820000881
# 414        bareilly plz . Pip bareilly Ã°ÂÂÂÃ°ÂÂÂ®...
# 415        \nVery poor performance in our area \nLast 3...
# 416      After deactivation service again u stole some ...
# 417      Reminder 21\nWorst vodafone    https://twitter...
# 418      How many mobile#are running over same IMEI.Ple...
# 419      How many mobile#are running over same IMEI.Ple...
# 420      How many mobile#are running over same IMEI.Ple...
# 421        \nYour number is continuously not reachable ...
# 422      Here is Download Speed 0.28 Mbps Ã°ÂÂÂ\nMos...
# 423      Ã Â¤ÂÃ Â¤Âª Ã Â¤Â¸Ã Â¤Â¿Ã Â¤Â°Ã Â¥ÂÃ Â¤Â«Ã Â...
# 424        when you don't act fair or just, your own (i...
# 425
# 426       I have cleared all my bills but its been 1 mo...
# 427      More than 36+ hour's, no response from you.\nV...
# 428        Ã Â¤ÂµÃ Â¥ÂÃ Â¤Â¡Ã Â¤Â¾Ã Â¤Â«Ã Â¥ÂÃ Â¤Â¨ Ã...
# 429       Is this your support? pic.twitter.com/OkrirjiUQj
# 430        wowww amazing to see the customer service th...
# 431       you are going to lose a lot of business from ...
# 432      Phle apne service shi kro....tum log sirf sbka...
# 433       https://support.apple.com/en-in/HT203078#:~:t...
# 434       What is this?? It doesn't matter for you to c...
# 435      Is there any update on this? I am not able to ...
# 436        how to check message balance for unlimited pack
# 437      Dear Vodafone is really very behind in offerin...
# 438      Dear Vodafone, I want to get my number MNP in ...
# 439      Dear Vodafone, I want to get my number MNP in ...
# 440       you all have become the worst network provide...
# 441       I have cleared all my bills for my postpaid v...
# 442       why can't you calll me back! I'm sick and tir...
# 443       India took almost 30 min to post a twotter ei...
# 444      Can you share me good plan and can tell me how...
# 445                                   your service is Hell
# 446      Just reminding that  has not fired this Hindup...
# 447        \n#VodafoneIdea shameless negligence of Voda...
# 448        ÃÂ§ÃÂÃÂ§ ÃÂ¹ÃÂ§ÃÂÃÂ²ÃÂ ÃÂ­ÃÂ¯ Ã...
# 449       Appellate Office trying to fool me again! Cla...
# 450       Even after your confirmation I am yet to rece...
# 451       I need  Proof of my confirmation to start wha...
# 452       Calling 199 to Vodafone but it's showing Jio ...
# 453      1 year 1 month 23 days and counting. Refund my...
# 454       pathetic network service plus customer servic...
# 455      Please guide how to switch to #volte on my #ip...
# 456      Yes Anusha really true Ã°ÂÂÂ Changing the n...
# 457       Poor network in pin code no 700119. Are you p...
# 458       Worst Service & Experience !!! Making money b...
# 459      No Reply from vodafone.. no  speed in internet...
# 460       ..Why problem still not being resolved in 3 d...
# 461       please try to understand the urgency of your ...
# 462           worst network experience in all time. \n
# 463      I donÃ¢ÂÂt use your service. I have been req...
# 464       Such poor service from Vodafone India. DidnÃ¢...
# 465               are you guys going to resolve the issue?
# 466      Ã Â¤ÂÃ Â¤Â¯Ã Â¤Â°Ã Â¤ÂÃ Â¥ÂÃ Â¤Â² Ã Â¤ÂÃ Â...
# 467      Why ? we speak with you. You do same thing... ...
# 468      Vodafone is trash. Its connection costs too mu...
# 469      with \nladies Ã¢ÂÂÃ¯Â¸ÂÃ°ÂÂÂand gentleme...
# 470                    sir please give  update on my issue
# 471      idk what youÃ¢ÂÂre talking about, i thought ...
# 472      I just donÃ¢ÂÂt belive that anonymouse dosen...
# 473      ÃÂello therÃÂµ,\n\nÃÂÃÂ°nt tÃÂ¾ eÃÂ°si...
# 474       I don't know how to treat you? If my problem ...
# 475      It's been four days now. My messages seem to b...
# 476      Hi , I did DM my no. DidnÃ¢ÂÂt see any actio...
# 477       Worst network ever experienced. No network co...
# 478       my vodafone mumbai simcard has some connectiv...
# 479                                              Same here
# 480        Customer care se baat krne ka option htaa di...
# 481                                  ItÃ¢ÂÂs 9899877321.
# 482      \n\n\n \nVodafone idea Ltd store are doing fra...
# 483       I have raised request.thorugh sms for call re...
# 484      Why my bill generated even services not given ...
# 485       this is what I expect?\nYour 4G network is wr...
# 486                           need help. Please reply soon
# 487       last month i was charged for international ro...
# 488                                          Still waiting
# 489       any plan to improve your network? Or you just...
# 490       Respected sir/ Mam\nI am Sukanta a loyal cust...
# 491        Their Executive stole money from my mom when...
# 492                       Coward has protected his tweets!
# 493         Have already texted you long back #happytohelp
# 494      I know it's very difficult time for you too!! ...
# 495      Haha  is down right crap. I had to get a seper...
# 496      Hi #Vodafone #vodafoneindia  chk it   https://...
# 497      I have recharged with 599 plan during double d...
# 498      No proper response to the private message. You...
# 499      So I guess I should forget that I have a vodaf...
# 500      . why are you defending Jihadi ? IÃ¢ÂÂm canc...
# 501       ported into vodafone.  Not getting network si...
# 502       one of the worst service provider. You guys e...
# 503       \nI have been trying to reach yoir costumer c...
# 504       I am getting call from my own number. Please ...
# 505      Dear sir,\nVodafone not returning security amo...
# 506       I recharged my number while an existing pack ...
# 507       still facing many  problemÃ°ÂÂ¤Â·Ã°ÂÂÂ»Ã¢Â...
# 508      I have messaged you my number related to this ...
# 509      Which network is best in noida\nSince mobile c...
# 510                                             Data chori
# 511                                 U will never get reply
# 512      \nand after the reacharge I only receive 1.5 G...
# 513       \nHello\nMy Top-up expired on 9'th June 2020....
# 514       I am using Vodafone network from last 5 years...
# 515      What a pethetic customer experience. No one ca...
# 516       \nVodafone 4g not working in Juhu \nKindly do...
# 517        Its been 4 days since i complained for inter...
# 518                       still hoping for reply from you.
# 519      Hi  pls chk attachment this is how you Serving...
# 520      Why to deleteÃ Â¥Â¤  Let everyone read it and ...
# 521      Bakwas messanger hai broÃ Â¥Â¤  Salo ne compla...
# 522        kindly resolve the issue at my premisses. I ...
# 523      Your cc is providing I'd vodafone.del.com whic...
# 524       I complained regarding the service and charge...
# 525      Very sad  , getting no reply from vodafone  ht...
# 526      Hi ,\n \n  \n Please reverse the unnecessary c...
# 527          Vodafone when I complained u numerous time...
# 528      Remove this late charge. We had talked to cust...
# 529                                                Ported*
# 530       Hi there are so many problems in your data ne...
# 531      Bye bye  and Joined back to  Ã°ÂÂÂÃ°ÂÂÂÃ...
# 532       #nothelping look at my screen shot Vodafone s...
# 533       I have a prepaid plan in which I get free mes...
# 534                            Morning 11:00 AM - 12:00 PM
# 535      Waiting for reply on broken, wrong URL Link sh...
# 536      #Indians about to Bankrupt  Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°...
# 537      \n WAITING FOR YOUR REPLY !!\n REPLY BACK ASAP...
# 538      Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ¤...
# 539                   need help pic.twitter.com/ivULDJJf1o
# 540      Hi,\nI am having a network issue sometime when...
# 541      What the hell is this happening... Is this a r...
# 542                  For what you are waiting my response?
# 543       \nÃ Â¤ÂµÃ Â¥ÂÃ Â¤Â¡Ã Â¤Â¾Ã Â¤Â«Ã Â¥ÂÃ Â¤Â¨ ...
# 544      Isme koi galat nhi h  bhi vesa hi nikla sharm ...
# 545                      Interesting now  is lying too...!
# 546      We respect you and wish our concern solved ami...
# 547      As mentioned earlier I'm no more interested in...
# 548      You ask for number in public but I haven't rec...
# 549      Ã Â¤ÂÃ Â¤Â Ã Â¤Â®Ã Â¥ÂÃ Â¤ÂÃ Â¤Â¨Ã Â¥Â Ã ...
# 550      We have visited erode vodafone store after loc...
# 551      Ã Â¤Â¬Ã Â¤Â¸ Ã Â¤Â¬Ã Â¤Â¿Ã Â¤Â² Ã Â¤ÂµÃ Â¤Â¸Ã ...
# 552      Refund my money asap as i haven't requested th...
# 553      You are right because the results are unbeliev...
# 554                                      Customer service*
# 555       your advertise happy to help is happy to harr...
# 556      There customer is worst.....they cant compete ...
# 557      Ek dum sahi bole ho \nYaha yahi chutiyap hota ...
# 558              Sahi bol rhe ho bhai useless company h mc
# 559         You literally need to improve your services...
# 560       We are a vendor from Assam Circle whose payme...
# 561        This is my second tweet, your service is rea...
# 562      You said the issue will be resolved by 9th .. ...
# 563      Usse bhi ghatiya words do bhai..yeh log yeh bh...
# 564      You guys are just busy in promoting your produ...
# 565       we have given a request reacivate our company...
# 566
# 567        You guys still havent been kicked out of India?
# 568       I have raised a complain on feb 2020 \nsent m...
# 569      I have raised a complain on feb 2020 \nsent ma...
# 570       How many times I have dropped emails and brou...
# 571      Any network is worst than   please let me know...
# 572      Day 662 of Protest:  please reply to Lama Ji. ...
# 573                        \nThanks, considering the same.
# 574      I'm getting 2g services in my area since many ...
# 575      Paul thoda ruk bhai, agar problem solve nahi h...
# 576      Still waiting for the update. My Number is: 98...
# 577        I have not requested for any dialer tone . A...
# 578       dekh lo apni asliyat....DM your no. Sorry for...
# 579       would you be able to marshal your focus abili...
# 580      Have some decency and try to reply. Who ever u...
# 581      Sir,\nGo for BSNL landline and Wi-Fi \nLife wi...
# 582      Ur company will be closed soon according to fu...
# 583      First give a decent service for internet. Ur m...
# 584      Do check your direct message. Hope you guys ch...
# 585          I have idea Prepaid & cannot tolerate this...
# 586                                               is MC BC
# 587                                      Still no response
# 588       how can I port my  number to your network wit...
# 589       You have pathetic Network   Every time my fri...
# 590      Thats new Hinduphobe !! WhatÃ¢ÂÂs next secul...
# 591      My alternative number have been sent to u twic...
# 592       Ã Â¤Â®Ã Â¥ÂÃ Â¤Â°Ã Â¥Â Ã Â¤ÂÃ Â¤ÂÃ Â¤ÂªÃ ...
# 593        Ã Â¤ÂªÃ Â¥ÂÃ Â¤Â°Ã Â¥ÂÃ Â¤ÂµÃ Â¥Â Ã Â¤ÂÃ...
# 594         itni pathetic internet speed hain, paise 4g...
# 595       Dear Sir/ Madam,\ni am facing VERY SLOW INTER...
# 596       COMPLAINT ABOUT: \nBAD Quality Of Voice & Cal...
# 597                 https://youtu.be/OF3kAN9YwYMÃÂ \n
# 598       awaiting for response.. situation getting wor...
# 599       I am not going to pay the bill until resolution.
# 600      I have already shared the details via DM, over...
# 601      Ã Â¤ÂÃ Â¤Â¤ 7 Ã Â¤Â¦Ã Â¤Â¿Ã Â¤Â¨Ã Â¥ÂÃ Â¤Â ...
# 602      Issue doens't solve, I will go for portability...
# 603       You have been told that now there are two acc...
# 604                                         No call still.
# 605      Superbb network AIRTEL Ã°ÂÂÂ¯\n       pic.tw...
# 606      #vodafone cheap service providers ..\nif you s...
# 607      Ã Â¤Â¸Ã Â¤Â®Ã Â¤Â¸Ã Â¥ÂÃ Â¤Â¯Ã Â¤Â¾ Ã Â¤ÂÃ Â...
# 608                            I have replied please check
# 609       facing network issues from past two three day...
# 610            Thanks. I have DMed you my contact details.
# 611      Right Now getting only 17kbps speed        pic...
# 612      Even their own app is not getting load        ...
# 613      Took more then 4 minutes and still trying to p...
# 614      We have given request to reactivate our no on ...
# 615      Ã Â¤ÂÃ Â¥ÂÃ Â¤Â issue Ã Â¤Â¨Ã Â¤Â¹Ã Â¥Â  Ã...
# 616      With such a slow speed, i cant post anything o...
# 617       trying your customer care  but nobody is pick...
# 618       is changing plans by self without any intimat...
# 619      My issue is finally resolved.This was only bec...
# 620                   Till now above grievence not solved.
# 621      Had been charged 99 INR for international Roaming
# 622      #ShameVodafone almost 45 days u can't revert a...
# 623      Till now your assurance not oblgade we have wa...
# 624                                  Jio is no good either
# 625                                Refund toh bhul ji jao.
# 626                                           6th reminder
# 627       Facing continuous down network issues very fr...
# 628      I am able to get other messages some time. Can...
# 629         have lots of time request to you for Chang ...
# 630       ye toh haal h tumhare network ka.\nKya krein ...
# 631                       Thanks for clarity in your mail.
# 632      I purchased new connection of  prepaid but con...
# 633      Why him? Every Musl!m says your god is fake. C...
# 634      Please solve the internet connection in Vijaya...
# 635      Aaaaaannnnd if that wasnÃ¢ÂÂt enough, you se...
# 636      My balance expiry date is on 29/06/20 and lie ...
# 637                                Do you have any problem
# 638      I am using a postpaid connection why will I ha...
# 639      Above complaint not yet addressed. Pls take ur...
# 640        no information, not notices no network. Real...
# 641       no resolution provided yet... bill has been r...
# 642       do we have #volte in #kerala is there calling...
# 643      We need urgent intervention to activate our mo...
# 644        this is to bring your kind attention that me...
# 645       \n\nI have don't use Vodafone internet but Vo...
# 646      Those are dont have any option please send a P...
# 647      Hey  your network is the worst in my area .l m...
# 648         is it compulsory to recharge from ur store ...
# 649      That's sweet ... Isn't it   .... Though Cyclon...
# 650       still no response from Vodafone for proper so...
# 651      #BREAKING #Anonymous\n#QAnonUK #NewsAlert #Tru...
# 652       i am not able to send msg or receive msgs in ...
# 653                   Ã°ÂÂÂ Ã°ÂÂÂ Jio Worst port in
# 654      Let it be.\nI am done, this has happened 3 tim...
# 655         \nToday I recv this msg from Vodafone, as p...
# 656       Not 4g srivice not available.and volte srivic...
# 657      ItÃ¢ÂÂs been more than 12 hours but still th...
# 658      Ab lagta hai twitter pe har din vodafone ko tw...
# 659       Have been waiting since morning for your call...
# 660      Khuch nhi hota hai usake bad message ata hai k...
# 661      Hey  can you increase the interval of your net...
# 662         Turabo net naam badal kar bellgadi 2g net bolo
# 663      Thanks Harsha, good to know your team closed t...
# 664       hello, y is ur mobile connection (network) is...
# 665      Can you define how can one internet download c...
# 666       why deducted my balance in the name of caller...
# 667                    my 3G and 4g are not working at all
# 668         \n\nHello, We are happy to share that we ha...
# 669        \nPorted out my number from Vodafone to Airt...
# 670      Kya sadi hui bakwas sarvice dete ho  thaka huv...
# 671       \nI am porting out from your network as you h...
# 672       chor hai toh hum kotwal hai. Ulta chor kotwal...
# 673      Now I again get message from Vodafone executiv...
# 674      I seriously don't know how is the issue resolv...
# 675      How many times you will apologize ? Tell you b...
# 676      Is there one open in PIN code 500032 area i.e ...
# 677      Really! I hope u know English,  But its seems ...
# 678         \nVery pathatic service of Vodafone .\nI us...
# 679       i'm getting literally a 2G net speed on your ...
# 680      Received a response on 7th Jun that any credit...
# 681                      Chor hai ek number k nahi karenge
# 682      I have twice because Iv tried of three differe...
# 683                                       Have send you no
# 684       up Ã Â¤ÂÃ Â¥Â Ã Â¤ÂÃ Â¤Â¿Ã Â¤Â²Ã Â¥Â Ã Â¤...
# 685       Recharge ka paisa wapase kardo basss issi pai...
# 686      Been trying to call  but cant get a human on c...
# 687      Vodafone plz solve my problem i am sufferin ne...
# 688      Many times I raised d complaints but result is...
# 689                              still waiting your reply.
# 690      I have replied you already and again replied y...
# 691      I tried to change my Vodafone postpaid plan .....
# 692      Thnx for advertising for Vodafone ... I tried ...
# 693                              no 4G network last 3 days
# 694       awaiting reply from your side, please don't e...
# 695       facing network issue last 3 days. Pin code 42...
# 696                                                   done
# 697      AgainÃ°ÂÂÂ ....ok done that for u, check ur...
# 698       you guys suck man .. your service sucks your ...
# 699       Ã Â¤Â¬Ã Â¤Â¹Ã Â¥ÂÃ Â¤Â¤ Ã Â¤Â¹Ã Â¥Â Ã Â¤ÂÃ...
# 700       Mp Nagar Zone 2 ka vodafone store open ho rah...
# 701      Bhai vodafone ji paise wapase kardo jaldi bas ...
# 702      IÃ¢ÂÂve already spoken to multiple people ov...
# 703                                          I cant either
# 704       pls call me, its an emergency.  https://twitt...
# 705      Hey April! This shouldn't be the case, please ...
# 706                               Ã°ÂÂÂÃ°ÂÂÂÃ°ÂÂÂ
# 707         why canÃ¢ÂÂt I make outbound calls? Ã°ÂÂ...
# 708      You havenÃ¢ÂÂt solved my problem, Neither to...
# 709      I want to port my  number to  \nAny doorstep s...
# 710       No data connectivity and signal loses fr more...
# 711       I have opted for porting my vodafone number a...
# 712      Bhut jldi  karyvahi ki Jayegi..tb tk.. SIM por...
# 713                                They will  never solve.
# 714       Its about  20 days since after Amphan hit in ...
# 715      Pathetic customer service by . I couldn't chan...
# 716       \nNow you dear tell me what to do. You said o...
# 717      ItÃ¢ÂÂs been 12 days and no one even bother ...
# 718       I hope my wifi issues are resolved by this we...
# 719        my Relationship number 14XXX45, I have place...
# 720       Ã°ÂÂÂ­Ã°ÂÂÂ­Ã°ÂÂÂ­ 2g network de rahe h...
# 721        have shame shame , am I living in jammu kash...
# 722       i tried calling the customer care number and ...
# 723       is not ready to solve my issue infact they ca...
# 724       \n\nKindly update, facing the same issue.\n\n...
# 725       Do please let me know how a prepaid user have...
# 726          Vodafone and airtel Very Bad service provided
# 727      Hi   - Issue till not resolved. \nThe automate...
# 728        \n\nYour internet used to work good, when I ...
# 729      Sir I have done this thing so many times that ...
# 730      You just look at thread how much long i have w...
# 731      i have DM my alternate number, plz solve this ...
# 732      Dear Akshay, \nReason was already informed and...
# 733      I definitely Join you .   Close your services ...
# 734      Hi Team, what's the standard signal strength f...
# 735       Ã Â¤ÂÃ Â¥Â Ã Â¤ÂÃ Â¥ÂÃ Â¤Â¡Ã Â¤Â¼Ã Â¤Â¨Ã ...
# 736      Hi, try calling 198 instead. I was able to con...
# 737        Today I hv recharged with Rs.39/- as per the...
# 738      Installation of tower.. In every hour was a JU...
# 739                     Already dm you my all the details.
# 740       Ã Â¤Â®Ã Â¥ÂÃ Â¤ÂÃ Â¥Â Ã Â¤Â¬Ã Â¤Â¹Ã Â¥ÂÃ ...
# 741          \nI have even tried instructions at the fo...
# 742       Hi Team, I had accidentally recharged my neig...
# 743       What a disgusting quality of voice quality yo...
# 744                                          I have dm you
# 745       after  d merciful  #NisargaCyclone d network ...
# 746                                             Reminder 1
# 747      Hey  \nIs this your definition of 4g?  pic.twi...
# 748       Vodafone's service is very bad, internet has ...
# 749           Hi, more than 24hrs, no onehas contacted me.
# 750       I am on the DND list why I am getting such st...
# 751       my internet connection is as it is , itÃ¢ÂÂ...
# 752         shame to nation that these service provider...
# 753         till date there is no resolution from from ...
# 754        I've been unable to use data on my phone for...
# 755         \n\nStrange for me , SHAME for airtel,\nPri...
# 756       Dear Team I am using you Sim your Voice call ...
# 757
# 758      Hello Team, in spite of repeated requests, Rs....
# 759      Today's data wastage due to bad speed    pic.t...
# 760                    DMed...waiting for the response now
# 761                        Tell me the exact procedure bro
# 762      For god sake .. keep ur data with u .. i wanna...
# 763         .. See what's your status. Just sent a comp...
# 764      1: Ã Â¤ÂÃ Â¤ÂªÃ Â¤ÂÃ Â¥Â Ã Â¤ÂÃ Â¥ÂÃ Â¤Âµ...
# 765      Today's data wastage due to bad speed    pic.t...
# 766      I didn't get any reply from you guys .but tick...
# 767
# 768
# 769
# 770
# 771
# 772
# 773                                                    \n
# 774      Main source of income for  is by looting genui...
# 775       is giving pathetic speed yet again. twice a w...
# 776      FRC is already done at the time of number migr...
# 777      Have replied to ur message there also. I got j...
# 778      Hi..I dnt know what else you need. I have prov...
# 779          ... Good move friend. I am facing same pro...
# 780      Please do. \nI need this sorted out and also n...
# 781       please provide vodafone 4G network .  Not ide...
# 782       Dear sir now lockdown is over and hope your s...
# 783       I am currently on international roaming and I...
# 784      Jio is doing superb in terms of providing serv...
# 785       30 march se hamesha complaint kiya hu calls p...
# 786      7 days, \n168 hours, \n10080 seconds,\n\nTo th...
# 787       claim superior network coverage, yet a simple...
# 788        I have already provided the details asked in...
# 789      Hi \nIt a long trail of mails and several call...
# 790      Just curious... How is that the Airtel stores ...
# 791      Dear   5 ghnte call krne k bad teri team ne nu...
# 792                              Please call on 8424014810
# 793      Hello Team, in spite of repeated requests, Rs....
# 794      Hi \nIt a long trail of mails and several call...
# 795                                    They will not reply
# 796      Ã Â¤Â¤Ã Â¥ÂÃ Â¤Â¯Ã Â¤Â¾Ã Â¤Â¨Ã Â¥Â Ã Â¤ÂÃ Â...
# 797                               Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£
# 798                I have an issue about my bill charges??
# 799        is this the pathetic service you give to you...
# 800      They will reply to you with their fucking temp...
# 801       you are very bad serviceÃ°ÂÂÂ Ã°ÂÂÂ Ã°ÂÂ...
# 802      Ã Â¤Â®Ã Â¥ÂÃ Â¤Â¬Ã Â¤Â¾Ã Â¤ÂÃ Â¤Â² Sanitizer...
# 803       are you not in network ?, have you also shift...
# 804      After one year suddenly someone has woke up & ...
# 805                    why is your website not working????
# 806          mtlb budhbak banaya Ã°ÂÂÂ¹ pic.twitter.c...
# 807      Ã Â¤Â®Ã Â¤Â¾Ã Â¤ÂÃ Â¥ÂÃ Â¤Â¯Ã Â¤Â¾ Ã Â¤ÂÃ Â...
# 808      Why are you wasting so much money on commercia...
# 809        no one is there to help us and share the rea...
# 810      Ã Â¤Â¤Ã Â¥ÂÃ Â¤Â®Ã Â¤ÂÃ Â¥Â Ã Â¤Â¸Ã Â¥ÂÃ Â...
# 811      No response till now from your end.. Why don't...
# 812       please cancel this and revert my money back. ...
# ...
# 20777      \nIt's quite disservice during Covid 19 time...
# 20778     I have been unable to send SMS for the last w...
# 20779    Why should we recharge , I suggest no one shou...
# 20780     and  sabse baddest network of India.\nDon't k...
# 20781                           pic.twitter.com/YVKMQoWsq6
# 20782    What an IDEA.. no reply on customer's problem ...
# 20783     Dear  CEO Ravinder Takkar, My services is hol...
# 20784                            Haha...get an Idea sirjee
# 20785                                             Ã°ÂÂÂ
# 20786     no pending bill only for may is due payment d...
# 20787    Let me get my money back from the unethical th...
# 20788    People near a village named Tikra near Hargaon...
# 20789       resistered complain in Feb, voda provide so...
# 20790    But why are these deductions happening when I ...
# 20791      itÃ¢ÂÂs already 10 days but no resolution ...
# 20792       Yess, please rectify or make me to port my no.
# 20793                      I have no IDEA at all..Ã°ÂÂÂ
# 20794    First, 09 May 2020 then 18 May 2020 and then t...
# 20795     14 mails to customer care and 10 personal vis...
# 20796    Ã Â¤Â®Ã Â¥Â Ã Â¤Â
# Ã Â¤ÂªÃ Â¤Â¨Ã Â¤Â¾ Ã Â¤ÂªÃ ...
# 20797     bsdk Teri*******t \n\nGadhe ki gand se ganda ...
# 20798                           pic.twitter.com/rNJPdwhMQH
# 20799     Any way I can port to Airtel in this lockdown...
# 20800    I have no alternative no. And don't care about...
# 20801        What do u think the scrip will do tomorrow...
# 20802                                Same problem till now
# 20803                                   Please check inbox
# 20804     will not pay single rupees....without my reso...
# 20805               Another one pic.twitter.com/v3fxxK1WPV
# 20806     Wants to switch from Airtel to your network ,...
# 20807    I have already done that and this is not my co...
# 20808      sir,  not calling my own number and telling ...
# 20809    Surprise Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ¤Â£Ã°ÂÂ...
# 20810    Finally had a word with your customer executiv...
# 20811     &  These 2 Operators Providing Worst Network ...
# 20812     plz reply my all messages and active my Netfl...
# 20813    Third Class Service.. \nI m suffering since la...
# 20814    Chor hai Vodafone company wale.  Humara balanc...
# 20815    Really Annoyed With Vodafone & Idea Services  ...
# 20816     I recharged my number with 39 today for which...
# 20817    chor hai Vodafone company wale har month balan...
# 20818     irregularly network problem ho rhi hai kai di...
# 20819    This is called    Waao 4G speed, Fir bhi saram...
# 20820    Hey do you still need help with this? I can fi...
# 20821      its 2 days past but haven't received the Ans...
# 20822     https://twitter.com/noufalp90/status/12432485...
# 20823     still not response to my network issues. All ...
# 20824    I hv asked 4 refund becz this s happening with...
# 20825              Aisha counting on your reply! Thank you
# 20826    How are people with only  network surviving?\n...
# 20827                   kya bolna hai inko paaji? Ã°ÂÂÂ
# 20828    Your reply is unsatisfactory, anyways, thanks ...
# 20829    Dear,\n  how d hell dis useless network  is cl...
# 20830     Kindly do the needful.Still no any response f...
# 20831    And theyÃ¢ÂÂre here to defend themselves :) ...
# 20832     Vodafone network connectivity is very poor in...
# 20833    The same information was taken from me as on 0...
# 20834                              7417525313  #socalled4g
# 20835    I didn't receive any CALL from  regarding my i...
# 20836    I would suggest you to ask anyone of your area...
# 20837    Thanks  for your  interrupting internet servic...
# 20838         Poor network from last 2 days  Please check.
# 20839    Hey  I am getting this message 'outgoing call ...
# 20840          I did reply you there. Awaiting your reply!
# 20841    Since yesterday network is not working in Para...
# 20842    I will only respond if you are gonna give 3 mo...
# 20843     why to pay for 4G services when you can provi...
# 20844    same did happened to me and once and for all I...
# 20845      CAN WE PLEASE STOP THE CORONA VIRUS WARNING ...
# 20846     it was better to be on idea your takeover is ...
# 20847    Very disheartening to say that the services ar...
# 20848      #VodafoneIdea #Vodafonedown\nSir Ã Â¤ÂÃ Â¤Â...
# 20849      worst service since 2 days IÃ¢ÂÂve not bee...
# 20850         Request you to setup exchange in our vill...
# 20851    The same message u did me as on 18 May 20 #Mac...
# 20852    I dont have My Vodafone App on my phone. Is Vo...
# 20853    I have lot of patience ...that's why I waiting...
# 20854     \nDo you still need payment?  pic.twitter.com...
# 20855     4g net not working in pali. Solve this matter...
# 20856       After 48hrs there is no response. It has be...
# 20857      see ur poor connectivity and ur #socalled4g ...
# 20858                                , Do check the inbox.
# 20859    Ã Â¤Â®Ã Â¥ÂÃ Â¤Â°Ã Â¥Â Ã Â¤Â¨Ã Â¤Â®Ã Â¥ÂÃ Â...
# 20860     Has your auto reply email system gone mad, I ...
# 20861    #ravindertakkar\nVery wrost 4G network at my h...
# 20862     \nVery poor connectivity in agra, up plzz res...
# 20863    I am tired of daily receiving the same replies...
# 20864    Thnks for quick response. Sharing details thro...
# 20865     pl stop pesky calls from LIC, VODAFONE AND MA...
# 20866    Hello Aisha, kindly please mention the number ...
# 20867     \nI am using 4g VOLTE sim and face slow inter...
# 20868     :- Not able to open vodafone india website fo...
# 20869         Thanks you for your reply.but it is restored
# 20870     A Crap Network At , No Call Going Through, Da...
# 20871    Ã Â¤Â®Ã Â¥ÂÃ Â¤Â Ã Â¤Â¬Ã Â¤Â¹Ã Â¥ÂÃ Â¤Â¤ Ã ...
# 20872
# 20873    Ã Â¤ÂÃ Â¤Â¹Ã Â¤Â¾Ã Â¤Â Ã Â¤ÂªÃ Â¤Â° Ã Â¤ÂÃ ...
# 20874     one of your executive called me right now ans...
# 20875
# 20876                                        Bhai ThankYou
# 20877     what about my network related issue. Come up ...
# 20878    How long can you stare at this image when you ...
# 20879    It's time to say goodbye to    after associati...
# 20880                        My alternate no is 9698380662
# 20881     I already gave my dertails.. Find in your system
# 20882    Its so sad.. If you dont havr my details avail...
# 20883                             Stay strong sis Ã°ÂÂÂ
# 20884     Its for . That app isnt urs. U r way better off.
# 20885    Forgot about good network. I've no 4G for 11 d...
# 20886     \nI have recieved call from your team they to...
# 20887    Got a call from executive but still query is o...
# 20888       buy new 4G spectrum.because internet speed ...
# 20889    I've no 4g for 11 days now. My nearby tower st...
# 20890    Your surprises suck... You activate a old numb...
# 20891    This is really ridiculous. You just send an ap...
# 20892     https://twitter.com/mamad_s143/status/1267028...
# 20893      why not u resolve the issue immediately? Y u...
# 20894    , I do the same for several time but it's not ...
# 20895
# 20896     ..very very slow internet...even 2G on landli...
# 20897     https://twitter.com/mamad_s143/status/1264489...
# 20898     \nIncorrect data charges of INR 590 even post...
# 20899      massive invst2India in telecom hope2get grtr...
# 20900    you guys are very much useless.. Now the netwo...
# 20901                           Hey already done pls check
# 20902      Can't I Port-In my  postpaid number in Airte...
# 20903     ÃÂ§ÃÂÃÂªÃÂÃÂ§ ÃÂ´ÃÂ±ÃÂÃÂ© ÃÂ®ÃÂ...
# 20904     https://twitter.com/mamad_s143/status/1267078...
# 20905    How can we identity whether x number is belong...
# 20906      \nmy uncles balance was around Rs. 200. now ...
# 20907               \nAre you ALL clients of this mover...
# 20908    Are you getting good internet speed from Vodaf...
# 20909    Please check my response and share your findin...
# 20910     How do I update my GST details on the vodafon...
# 20911                       My concern is not resolved yet
# 20912    Since 6 months I am hearing the same.   Ã Â¤Â...
# 20913    Don't you have any India contact who can file ...
# 20914    Mobile network in Vodafone is not available in...
# 20915    It's completely fake guys... These vodafone pe...
# 20916    Payal, was this a joke? My complaint is 'I can...
# 20917        I feel like laughing now on vodafonein 's ...
# 20918                                    I also want port.
# 20919    Thanks but IÃ¢ÂÂm based in UAE so I canÃ¢ÂÂ...
# 20920      Ã Â¤Â®Ã Â¥ÂÃ Â¤Â°Ã Â¥ÂÃ Â¤Â Ã Â¤Â¬Ã Â¤Â¨Ã...
# 20921    Charged for 399 on 25th May. Problem with inco...
# 20922    Immediately file your complaint with all detai...
# 20923     my wife's phone has no network since two mont...
# 20924    An #idea that can change the world. Now it see...
# 20925     Thank you for the amazing service during lock...
# 20926     having a devastating experience with u r serv...
# 20927      what u say....\nÃ Â¤ÂÃ Â¤Âª Ã Â¤Â¸Ã Â¤Â¹Ã Â...
# 20928    I was dealing your turtle speed service before...
# 20929    No proper response from customer care. Only pr...
# 20930    Just another shitty day on  VDSL2 Broadband.  ...
# 20931     \nSir she is my brother   's colleague, plz h...
# 20932    Something similar is happening to one my frien...
# 20933    Big request to check ur DM How Many Times I sh...
# 20934    Bro u r committing a mistake,  they have a ver...
# 20935        network  hona chaiye na rechaege karne k liye
# 20936      please clarify that maximum how many SIMs ca...
# 20937      \nBig request to check ur DM How Many Times ...
# 20938    Big request to check ur DM How Many Times I sh...
# 20939     Sir\nKindly look into the matter.\nThanks\nÃ°...
# 20940     No Matters from how long you are using the Ne...
# 20941    Porting into #jio  will be better option rathe...
# 20942    Hello    #AirtelIndia\n\nWe have to port in yo...
# 20943                                          Switch to
# 20944                                       Ã¢ÂÂÃ°ÂÂÂ»
# 20945                    U stay in abu dhai  or in India ?
# 20946    . \nThere is someone from Mumbai who is morphi...
# 20947         This is how AIRTEL cares about their cust...
# 20948    Hye  Mazid ke alava y Is Area m sbki problem h...
# 20949    SimSlot1   No Network #HappyToHelp\n#GoVodafon...
# 20950
# 20951    Turbo net 4g is not available at pin code 3636...
# 20952    Issue is still not resolved. pic.twitter.com/6...
# 20953    Thanks a lot. Today again got an SMS from a co...
# 20954    Sahi m bhai bc chutiya bna rkha ha 2 mahine se...
# 20955    This is not only my problem this is our area p...
# 20956     - Not getting support from the customer care ...
# 20957                             Any time call me at once
# 20958    So is anyone checking this? You guys are very ...
# 20959    But phonpe still showing me double data offer ...
# 20960                             Mujhe bhi port krani hai
# 20961    \n\n\n\n\n\n\nWhen your engineer didn't came I...
# 20962          without Network  pic.twitter.com/IIHsOLJYUI
# 20963    Whatever you suggested not working. Refund the...
# 20964    Sim Slot 1 Vodafone Same on You   team Vodafon...
# 20965    Hello  Vodafone just spoke to me to your advis...
# 20966    Bina Network ke Recharge kya Mazak h pic.twitt...
# 20967    Big Reason Mentioned in Screenshot No Any Netw...
# 20968     where is double data , I recharged today 599Ã...
# 20969        Stop Looting Indian Consumer. .. Forget 5G...
# 20970    Hello arya just spoke to me to your adviser su...
# 20971    India's best 4g network... What a brilliant sp...
# 20972    No Network No Speed \nNo Network for Call...\n...
# 20973          https://twitter.com/MushtabaArshad/statu...
# 20974     Plato games app doesn't work properly in your...
# 20975           https://twitter.com/MushtabaArshad/stat...
# 20976                             sabse ghatiya 4G network
# 20977    Not getting any satisfied reply from you.\nNow...
# 20978    I have already done that. Ease check the case ...
# 20979    The top 3s but not satisfied with the  due to ...
# 20980                                            Lets see.
# 20981    Speeds have been low this month, postpaid spee...
# 20982    IÃ¢ÂÂve messaged my query twice but your guy...
# 20983    VODAFONE'S "LITTLE BROTHER" ...Ã°ÂÂ¤Â£Ã°ÂÂ¤Â...
# 20984    No one has called me.its been 24  http://hours...
# 20985             Some one tell me how to complain in TRAI
# 20986    Kindly share your screen shot and I shall make...
# 20987    #vodafonfraudÃ°ÂÂÂÃ°ÂÂÂ»\nYou idiot's tum...
# 20988      just canÃ¢ÂÂt imagine what a waste you are...
# 20989                                           ok. thanks
# 20990    See my voice calls is working fine as mentione...
# 20991    They stopped replying to me on mail and facebo...
# 20992    Good job on copy pasting tweets.. I have the s...
# 20993    Never matter that number doesn't have any inco...
# 20994                                            Pls reply
# 20995     https://twitter.com/Aghorababa/status/1267061...
# 20996    What the fuck personal details ???? DND ke baa...
# 20997    And how is that?\nItÃ¢ÂÂs been 2 days alread...
# 20998    Our village belongs to NCR still we face ntwrk...
# 20999      after 5 days received call from your consume...
# 21000    This was the plan I choose, but got a bill wit...
# 21001    It was not just the network, I also reported b...
# 21002    Abey Darindaron ke aulad..... Tumhara baap kab...
# 21003     - I got the call from  +91 6289-955727 at 16....
# 21004             Abhi DKBose ..... Teri maa ki chunni....
# 21005              No network & data speed in 2kbps in upe
# 21006    \n Abey Tumlog jhaago https://twitter.com/Agho...
# 21007    Here are atleast 2k mobile users but we don't ...
# 21008           When will you look into the inflated bill?
# 21009      i was an idea customer, why did you changed ...
# 21010    Hi   MyIdea app is not working for the past 1 ...
# 21011                           pic.twitter.com/4ynZ9Zm1Xh
# 21012    Dear  your network not at all working properly...
# 21013    Please check your messages Priya.. You guys ar...
# 21014                              Even God can't help you
# 21015    Could I get a call back between 530 and 6pm pl...
# 21016    Bad Experience with  on my number. Deduction o...
# 21017     my service request number is 4-66182393804.\n...
# 21018                                Hmm You can call now.
# 21019     completed a recharge of 295 INR for internati...
# 21020      pls stop Corona Callertunes itÃ¢ÂÂs enough...
# 21021     https://twitter.com/sleepofy/status/126674596...
# 21022        \n There is no response, please check how ...
# 21023     I too am getting these message since December...
# 21024    Since last 1 month I'm facing issue regarding ...
# 21025                                      Thanku vodafone
# 21026    I too am getting these message since December ...
# 21027    What is the point of recharging when you don't...
# 21028    Burst services Vodafone try to loot only custo...
# 21029    Also in my previous tweet, i have mentioned th...
# 21030        In my area as soon as there is power failu...
# 21031     Hi ! This is sahil i want to say something to...
# 21032    Please don't move on to Vodafone, it's a waste...
# 21033    Generate upc code and contact nearest vodafone...
# 21034    Provide me a working customer care number of y...
# 21035     \nI am using 9953992234 since ten years .no b...
# 21036    Very very poor internet speed on  and  network...
# 21037                         Airtel is better than voda .
# 21038     unfortunately this is not going in line with ...
# 21039    Haven't got any surprise? Ã°ÂÂÂÃ°ÂÂÂ Mor...
# 21040     Please check DM i have sent the numbers. Plea...
# 21041     Sorry to say but you was kidding me. In last ...
# 21042    I sent u my contact no. But still did not get ...
# 21043    dear   i have bn facing ur network problem for...
# 21044    rubbish i made many time   you didn't resolved...
# 21045    Why the caller tunes sound so horrible? if a s...
# 21046      what nonsense are u guys saying??? I'm getti...
# Name: clean_text, dtype: object

# %% [markdown]
# We can see that all mentions of @Vodafone have been removed as we wanted.

# %% [markdown]
# Step 2: We want to removing everything that is not a letter

# %% [markdown]
# ## Practise: Tokenise and Identify Special Instances of Tweets

# %% [markdown]
# ## Practise: Vectoriser

# %% [markdown]
# ## Theory: Understanding K-Means

# %% [markdown]
# ## Practise: Clustering with 8 centroids

# %% [markdown]
# ## Practise: Clustering with 2 centroids

# %% [markdown]
# ## Practise: Clustering with 2 centroids - Word Clouds

# %% [markdown]
# ## Practise: General Function Homogeneity in Cluster - Finding the optimal Cluster Number
